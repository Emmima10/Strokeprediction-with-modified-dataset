# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
data = pd.read_csv("stroke.csv", index_col=0)

# %%
data.head()
# Out:
#        gender   age  hypertension  alcohol_intake  heart_disease ever_married  \
# id
# 9046     Male  67.0           147               2              1          Yes
# 51676  Female  61.0           135               4              0          Yes
# 31112    Male  80.0           115               3              1          Yes
# 60182  Female  49.0           125               2              0          Yes
# 1665   Female  79.0           130               3              0          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# id
# 9046         Private          Urban             228.69  36.6  formerly smoked
# 51676  Self-employed          Rural             202.21   NaN     never smoked
# 31112        Private          Rural             105.92  32.5     never smoked
# 60182        Private          Urban             171.23  34.4           smokes
# 1665   Self-employed          Rural             174.12  24.0     never smoked
#
#        stroke
# id
# 9046        1
# 51676       1
# 31112       1
# 60182       1
# 1665        1

# %%
data['hypertension'] = data['hypertension'].astype(float) 
data['alcohol_intake'] = data['alcohol_intake'].astype(float)

# %%
data = data.drop("ever_married" , axis=1)
data = data.drop("work_type" , axis=1)

# %%
for column in data.columns:
    if data[column].dtype == np.number:
        continue
    data[column] = LabelEncoder().fit_transform( data[column] )

# %%
data = data.fillna(data.mean())

# %%
X = data.drop(["stroke"], axis=1)
Y = data["stroke"]

# %%
x_scaler = MinMaxScaler()
x_scaler.fit(X)
column_names = X.columns
X[column_names]=x_scaler.transform(X)

# %%
X.head()
# Out:
#        gender       age  hypertension  alcohol_intake  heart_disease  \
# id
# 9046      1.0  0.816895      0.858974        0.333333            1.0
# 51676     0.0  0.743652      0.782051        0.666667            0.0
# 31112     1.0  0.975586      0.653846        0.500000            1.0
# 60182     0.0  0.597168      0.717949        0.333333            0.0
# 1665      0.0  0.963379      0.750000        0.500000            0.0
#
#        Residence_type  avg_glucose_level       bmi  smoking_status
# id
# 9046              1.0           0.801173  0.301260        0.333333
# 51676             0.0           0.678875  0.215380        0.666667
# 31112             0.0           0.234159  0.254296        0.666667
# 60182             1.0           0.535793  0.276060        1.000000
# 1665              0.0           0.549141  0.156930        0.666667

# %%
X=np.array(X)
Y= np.array(Y)

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state = 2) 
X_res, Y_res = sm.fit_sample(X,Y.ravel())

# %%
print("After OverSampling, counts of label '1': {}".format(sum(Y_res == 1))) 
print("After OverSampling, counts of label '0': {}".format(sum(Y_res == 0)))
# Out:
# After OverSampling, counts of label '1': 2751
# After OverSampling, counts of label '0': 2751

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.metrics import binary_crossentropy

# %%
model = Sequential([
    Dense(32, input_shape=(X_res.shape[1],), activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(2, activation='softmax'),    
])

# %%
model.compile(optimizer=Adam(learning_rate = 0.0001),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(X_res,Y_res,validation_split=0.1,batch_size=10,epochs=145,shuffle=True,verbose=2)
# Out:
# Train on 4951 samples, validate on 551 samples
# Epoch 1/145
# 4951/4951 - 1s - loss: 0.7126 - accuracy: 0.4676 - val_loss: 0.6355 - val_accuracy: 0.9165
# Epoch 2/145
# 4951/4951 - 0s - loss: 0.6707 - accuracy: 0.6599 - val_loss: 0.6412 - val_accuracy: 0.7604
# Epoch 3/145
# 4951/4951 - 1s - loss: 0.6460 - accuracy: 0.7334 - val_loss: 0.6175 - val_accuracy: 0.7804
# Epoch 4/145
# 4951/4951 - 1s - loss: 0.6190 - accuracy: 0.7497 - val_loss: 0.6109 - val_accuracy: 0.7132
# Epoch 5/145
# 4951/4951 - 1s - loss: 0.5872 - accuracy: 0.7649 - val_loss: 0.5795 - val_accuracy: 0.7677
# Epoch 6/145
# 4951/4951 - 1s - loss: 0.5521 - accuracy: 0.7742 - val_loss: 0.5291 - val_accuracy: 0.8076
# Epoch 7/145
# 4951/4951 - 1s - loss: 0.5219 - accuracy: 0.7796 - val_loss: 0.5126 - val_accuracy: 0.8040
# Epoch 8/145
# 4951/4951 - 1s - loss: 0.5000 - accuracy: 0.7841 - val_loss: 0.4828 - val_accuracy: 0.8203
# Epoch 9/145
# 4951/4951 - 1s - loss: 0.4859 - accuracy: 0.7813 - val_loss: 0.5120 - val_accuracy: 0.7931
# Epoch 10/145
# 4951/4951 - 1s - loss: 0.4753 - accuracy: 0.7847 - val_loss: 0.4737 - val_accuracy: 0.8185
# Epoch 11/145
# 4951/4951 - 1s - loss: 0.4684 - accuracy: 0.7865 - val_loss: 0.5136 - val_accuracy: 0.7895
# Epoch 12/145
# 4951/4951 - 1s - loss: 0.4630 - accuracy: 0.7859 - val_loss: 0.4717 - val_accuracy: 0.8149
# Epoch 13/145
# 4951/4951 - 1s - loss: 0.4594 - accuracy: 0.7873 - val_loss: 0.4720 - val_accuracy: 0.8185
# Epoch 14/145
# 4951/4951 - 1s - loss: 0.4559 - accuracy: 0.7879 - val_loss: 0.4870 - val_accuracy: 0.8040
# Epoch 15/145
# 4951/4951 - 1s - loss: 0.4536 - accuracy: 0.7889 - val_loss: 0.4490 - val_accuracy: 0.8240
# Epoch 16/145
# 4951/4951 - 1s - loss: 0.4513 - accuracy: 0.7907 - val_loss: 0.4956 - val_accuracy: 0.7967
# Epoch 17/145
# 4951/4951 - 1s - loss: 0.4502 - accuracy: 0.7891 - val_loss: 0.5026 - val_accuracy: 0.7877
# Epoch 18/145
# 4951/4951 - 1s - loss: 0.4487 - accuracy: 0.7885 - val_loss: 0.4930 - val_accuracy: 0.7985
# Epoch 19/145
# 4951/4951 - 1s - loss: 0.4475 - accuracy: 0.7916 - val_loss: 0.4626 - val_accuracy: 0.8113
# Epoch 20/145
# 4951/4951 - 1s - loss: 0.4467 - accuracy: 0.7912 - val_loss: 0.4969 - val_accuracy: 0.7949
# Epoch 21/145
# 4951/4951 - 1s - loss: 0.4455 - accuracy: 0.7893 - val_loss: 0.4675 - val_accuracy: 0.8094
# Epoch 22/145
# 4951/4951 - 1s - loss: 0.4441 - accuracy: 0.7903 - val_loss: 0.4950 - val_accuracy: 0.7967
# Epoch 23/145
# 4951/4951 - 1s - loss: 0.4432 - accuracy: 0.7920 - val_loss: 0.4553 - val_accuracy: 0.8221
# 4951/4951 - 1s - loss: 0.4105 - accuracy: 0.8142 - val_loss: 0.4484 - val_accuracy: 0.8457
# Epoch 89/145
# 4951/4951 - 1s - loss: 0.4096 - accuracy: 0.8180 - val_loss: 0.4268 - val_accuracy: 0.8566
# Epoch 90/145
# 4951/4951 - 1s - loss: 0.4091 - accuracy: 0.8196 - val_loss: 0.4383 - val_accuracy: 0.8494
# Epoch 91/145
# 4951/4951 - 1s - loss: 0.4089 - accuracy: 0.8164 - val_loss: 0.4509 - val_accuracy: 0.8421
# Epoch 92/145
# 4951/4951 - 1s - loss: 0.4078 - accuracy: 0.8204 - val_loss: 0.4600 - val_accuracy: 0.8403
# Epoch 93/145
# 4951/4951 - 1s - loss: 0.4078 - accuracy: 0.8190 - val_loss: 0.4588 - val_accuracy: 0.8403
# Epoch 94/145
# 4951/4951 - 1s - loss: 0.4075 - accuracy: 0.8162 - val_loss: 0.4222 - val_accuracy: 0.8621
# Epoch 95/145
# 4951/4951 - 1s - loss: 0.4072 - accuracy: 0.8196 - val_loss: 0.4544 - val_accuracy: 0.8439
# Epoch 96/145
# 4951/4951 - 1s - loss: 0.4067 - accuracy: 0.8200 - val_loss: 0.4694 - val_accuracy: 0.8367
# Epoch 97/145
# 4951/4951 - 1s - loss: 0.4062 - accuracy: 0.8206 - val_loss: 0.4654 - val_accuracy: 0.8403
# Epoch 98/145
# 4951/4951 - 1s - loss: 0.4054 - accuracy: 0.8219 - val_loss: 0.4394 - val_accuracy: 0.8530
# Epoch 99/145
# 4951/4951 - 1s - loss: 0.4051 - accuracy: 0.8231 - val_loss: 0.4639 - val_accuracy: 0.8330
# Epoch 100/145
# 4951/4951 - 1s - loss: 0.4050 - accuracy: 0.8190 - val_loss: 0.4101 - val_accuracy: 0.8584
# Epoch 101/145
# 4951/4951 - 1s - loss: 0.4043 - accuracy: 0.8194 - val_loss: 0.4141 - val_accuracy: 0.8657
# Epoch 102/145
# 4951/4951 - 1s - loss: 0.4042 - accuracy: 0.8198 - val_loss: 0.4306 - val_accuracy: 0.8566
# Epoch 103/145
# 4951/4951 - 1s - loss: 0.4035 - accuracy: 0.8208 - val_loss: 0.4393 - val_accuracy: 0.8494
# Epoch 104/145
# 4951/4951 - 1s - loss: 0.4024 - accuracy: 0.8225 - val_loss: 0.4024 - val_accuracy: 0.8639
# Epoch 105/145
# 4951/4951 - 1s - loss: 0.4022 - accuracy: 0.8221 - val_loss: 0.4794 - val_accuracy: 0.8330
# Epoch 106/145
# 4951/4951 - 1s - loss: 0.4021 - accuracy: 0.8231 - val_loss: 0.4407 - val_accuracy: 0.8494
# Epoch 107/145
# 4951/4951 - 1s - loss: 0.4014 - accuracy: 0.8221 - val_loss: 0.4767 - val_accuracy: 0.8367
# Epoch 108/145
# 4951/4951 - 1s - loss: 0.4013 - accuracy: 0.8221 - val_loss: 0.4952 - val_accuracy: 0.8203
# Epoch 109/145
# 4951/4951 - 1s - loss: 0.4011 - accuracy: 0.8231 - val_loss: 0.4577 - val_accuracy: 0.8385
# Epoch 110/145
# 4951/4951 - 1s - loss: 0.4005 - accuracy: 0.8231 - val_loss: 0.4858 - val_accuracy: 0.8276
# Epoch 111/145
# 4951/4951 - 1s - loss: 0.3993 - accuracy: 0.8229 - val_loss: 0.3885 - val_accuracy: 0.8693
# Epoch 112/145
# 4951/4951 - 1s - loss: 0.3997 - accuracy: 0.8231 - val_loss: 0.4493 - val_accuracy: 0.8421
# Epoch 113/145
# 4951/4951 - 1s - loss: 0.3988 - accuracy: 0.8247 - val_loss: 0.4480 - val_accuracy: 0.8457
# Epoch 114/145
# 4951/4951 - 1s - loss: 0.3981 - accuracy: 0.8235 - val_loss: 0.4371 - val_accuracy: 0.8494
# Epoch 115/145
# 4951/4951 - 1s - loss: 0.3982 - accuracy: 0.8243 - val_loss: 0.4549 - val_accuracy: 0.8403
# Epoch 116/145
# 4951/4951 - 1s - loss: 0.3979 - accuracy: 0.8247 - val_loss: 0.4295 - val_accuracy: 0.8530
# Epoch 117/145
# 4951/4951 - 1s - loss: 0.3969 - accuracy: 0.8263 - val_loss: 0.5173 - val_accuracy: 0.8113
# Epoch 118/145
# 4951/4951 - 1s - loss: 0.3972 - accuracy: 0.8243 - val_loss: 0.4612 - val_accuracy: 0.8385
# Epoch 119/145
# 4951/4951 - 1s - loss: 0.3959 - accuracy: 0.8255 - val_loss: 0.4850 - val_accuracy: 0.8294
# Epoch 120/145
# 4951/4951 - 1s - loss: 0.3961 - accuracy: 0.8261 - val_loss: 0.4336 - val_accuracy: 0.8457
# Epoch 121/145
# 4951/4951 - 1s - loss: 0.3959 - accuracy: 0.8251 - val_loss: 0.4261 - val_accuracy: 0.8530
# Epoch 122/145
# 4951/4951 - 1s - loss: 0.3950 - accuracy: 0.8281 - val_loss: 0.4264 - val_accuracy: 0.8530
# Epoch 123/145
# 4951/4951 - 1s - loss: 0.3951 - accuracy: 0.8265 - val_loss: 0.4454 - val_accuracy: 0.8421
# Epoch 124/145
# 4951/4951 - 1s - loss: 0.3938 - accuracy: 0.8259 - val_loss: 0.4300 - val_accuracy: 0.8494
# Epoch 125/145
# 4951/4951 - 1s - loss: 0.3935 - accuracy: 0.8299 - val_loss: 0.4497 - val_accuracy: 0.8403
# Epoch 126/145
# 4951/4951 - 1s - loss: 0.3931 - accuracy: 0.8269 - val_loss: 0.4880 - val_accuracy: 0.8203
# Epoch 127/145
# 4951/4951 - 1s - loss: 0.3929 - accuracy: 0.8277 - val_loss: 0.3967 - val_accuracy: 0.8675
# Epoch 128/145
# 4951/4951 - 1s - loss: 0.3924 - accuracy: 0.8285 - val_loss: 0.4419 - val_accuracy: 0.8439
# Epoch 129/145
# 4951/4951 - 1s - loss: 0.3917 - accuracy: 0.8289 - val_loss: 0.4210 - val_accuracy: 0.8530
# Epoch 130/145
# 4951/4951 - 1s - loss: 0.3909 - accuracy: 0.8285 - val_loss: 0.4414 - val_accuracy: 0.8439
# Epoch 131/145
# 4951/4951 - 1s - loss: 0.3911 - accuracy: 0.8299 - val_loss: 0.4180 - val_accuracy: 0.8548
# Epoch 132/145
# 4951/4951 - 1s - loss: 0.3902 - accuracy: 0.8299 - val_loss: 0.4364 - val_accuracy: 0.8494
# Epoch 133/145
# 4951/4951 - 1s - loss: 0.3904 - accuracy: 0.8287 - val_loss: 0.4240 - val_accuracy: 0.8584
# Epoch 134/145
# 4951/4951 - 1s - loss: 0.3898 - accuracy: 0.8303 - val_loss: 0.3979 - val_accuracy: 0.8639
# Epoch 135/145
# 4951/4951 - 1s - loss: 0.3897 - accuracy: 0.8293 - val_loss: 0.4528 - val_accuracy: 0.8421
# Epoch 136/145
# 4951/4951 - 1s - loss: 0.3882 - accuracy: 0.8322 - val_loss: 0.3727 - val_accuracy: 0.8802
# Epoch 137/145
# 4951/4951 - 1s - loss: 0.3886 - accuracy: 0.8293 - val_loss: 0.4392 - val_accuracy: 0.8457
# Epoch 138/145
# 4951/4951 - 1s - loss: 0.3879 - accuracy: 0.8289 - val_loss: 0.4110 - val_accuracy: 0.8566
# Epoch 139/145
# 4951/4951 - 1s - loss: 0.3880 - accuracy: 0.8303 - val_loss: 0.3854 - val_accuracy: 0.8711
# Epoch 140/145
# 4951/4951 - 1s - loss: 0.3875 - accuracy: 0.8301 - val_loss: 0.4102 - val_accuracy: 0.8566
# Epoch 141/145
# 4951/4951 - 1s - loss: 0.3864 - accuracy: 0.8307 - val_loss: 0.3646 - val_accuracy: 0.8820
# Epoch 142/145
# 4951/4951 - 1s - loss: 0.3861 - accuracy: 0.8334 - val_loss: 0.4642 - val_accuracy: 0.8330
# Epoch 143/145
# 4951/4951 - 1s - loss: 0.3860 - accuracy: 0.8313 - val_loss: 0.3918 - val_accuracy: 0.8693
# Epoch 144/145
# 4951/4951 - 1s - loss: 0.3856 - accuracy: 0.8305 - val_loss: 0.4456 - val_accuracy: 0.8457
# Epoch 145/145
# 4951/4951 - 1s - loss: 0.3852 - accuracy: 0.8320 - val_loss: 0.4271 - val_accuracy: 0.8566

# %%
#user_input=input("Enter the values one by one")
#user_input=user_input.split(",")


#for i in range(len(user_input)):
    # convert each item to int type
 #   user_input[i] = float(user_input[i])
# Out:
# Enter the values one by one1,67,147,2,1,1,228.69,36.60,1

# %%
#user_input = np.array(user_input)
#user_input = user_input.reshape(1,-1)
#user_input = x_scaler.transform(user_input)
#pred = model.predict(user_input)
#print(np.argmax(pred[0]))
# Out:
# 1

# %%
model.save("final.h5")

# %%
new_model = tf.keras.models.load_model('final.h5')

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 1,002
# Trainable params: 1,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_Testing5= np.array([[1, 6,85,0,0,0,100,22.0,2]])

# %%
X_Testing5=X_Testing5.reshape(1,-1)
X_Testing5=x_scaler.transform(X_Testing5)
Y_pred5=new_model.predict(X_Testing5)
print(np.argmax(Y_pred5[0]))
# Out:
# 0

# %%
import joblib

# %%
joblib.dump(x_scaler,'sc_scaler.pkl')
# Out:
# ['sc_scaler.pkl']
